# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

import matplotlib.pyplot as plt

from fake_signals import create_gaussian_transcient, create_sin_wave, create_chirp, plot_signal
from fake_signals import fake_EEG

# %%
t, y = create_sin_wave(f=5, length=7)
plot_signal(t, y, title='Sinus wave');
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
t, y = create_gaussian_transcient(f=5, length=7, mu=3.5)
plot_signal(t, y, title='Gaussian transcient wave');
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
t, y, fm = create_chirp(f_min=5, f_max=10, length=7)
plot_signal(t, y, title='Chirp');
plot_signal(t, fm, title='Frequency distribution', ylabel='Frequency [Hz]');
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
X = fake_EEG()
plt.figure()
[ plt.plot(X[c,:], alpha=0.7) for c in range(X.shape[0]) ];
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
